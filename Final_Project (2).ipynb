# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import logging 
logger = logging.getLogger()
fhandler = logging.FileHandler(filename='mylog.log', mode='a')
formatter = logging.Formatter('%(name)s - %(levelname)s - %(message)s')
fhandler.setFormatter(formatter)
logger.addHandler(fhandler)
logger.setLevel(logging.DEBUG)
logging.info('We are starting the data analysis in Jupyter Notebook')

# %% [markdown]
# ## Reading csv File

# %%
df = pd.read_csv('adult.csv')
logging.info('Imported data successfully.')

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week         country  salary
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  country         32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'country', 'salary'],
#       dtype='object')

# %%
df.describe().T
# Out:
#                   count           mean            std      min       25%  \
# age             32561.0      38.581647      13.640433     17.0      28.0
# fnlwgt          32561.0  189778.366512  105549.977697  12285.0  117827.0
# education-num   32561.0      10.080679       2.572720      1.0       9.0
# capital-gain    32561.0    1077.648844    7385.292085      0.0       0.0
# capital-loss    32561.0      87.303830     402.960219      0.0       0.0
# hours-per-week  32561.0      40.437456      12.347429      1.0      40.0
#
#                      50%       75%        max
# age                 37.0      48.0       90.0
# fnlwgt          178356.0  237051.0  1484705.0
# education-num       10.0      12.0       16.0
# capital-gain         0.0       0.0    99999.0
# capital-loss         0.0       0.0     4356.0
# hours-per-week      40.0      45.0       99.0

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.head()
logging.info('Starting EDA')
logging.info('Analysing relation between independent and dependant variable.')

# %%
#plt.figure(figsize = (16,9))
plt.hist(df['age'], edgecolor = 'black')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
#plt.figure(figsize = (16,9))
sns.histplot(x=df['age'],hue=df['salary'],bins=15)
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
#plt.figure(figsize = (16,9))
plt.hist(df['workclass'], histtype = 'bar')
plt.ylabel('Work Class')
plt.xlabel('Count')
plt.xticks(rotation='vertical')
plt.show()

# %%
#plt.figure(figsize = (16,9))
sns.histplot(y=df['workclass'],hue=df['salary'],bins=15)
plt.ylabel('Work Class')
plt.xlabel('Count')
plt.show()

# %%
#plt.figure(figsize = (16,9))
plt.hist(df['fnlwgt'])
plt.xlabel('fnlwgt')
plt.ylabel('Count')
plt.show()

# %%
#plt.figure(figsize = (16,9))
sns.histplot(x=df['fnlwgt'],hue=df['salary'],bins=15)
plt.xlabel('fnlwgt')
plt.ylabel('Count')
plt.show()

# %%
#plt.figure(figsize = (16,9))
plt.hist(df['education'], width = 0.5, histtype = 'bar')
plt.xlabel('education')
plt.ylabel('Count')
plt.xticks(rotation='vertical')
plt.show()

# %%
#plt.figure(figsize = (16,9))
sns.histplot(x=df['education'],hue=df['salary'],bins=15)
plt.xlabel('education')
plt.ylabel('Count')
plt.xticks(rotation='vertical')
plt.show()

# %%
#plt.figure(figsize = (16,9))
plt.hist(df['education-num'], width = 0.5, histtype = 'bar')
plt.xlabel('education-num')
plt.ylabel('Count')
plt.show()

# %%
#plt.figure(figsize = (16,9))
sns.histplot(x=df['education-num'],hue=df['salary'],bins=15)
plt.xlabel('education-num')
plt.ylabel('Count')
plt.show()

# %%
#plt.figure(figsize = (16,9))
plt.hist(df['occupation'], width = 0.5, histtype = 'bar')
plt.xlabel('occupation')
plt.ylabel('Count')
plt.xticks(rotation='vertical')
plt.show()

# %%
#plt.figure(figsize = (16,9))
sns.histplot(x=df['occupation'],hue=df['salary'],bins=15)
plt.xlabel('occupation')
plt.ylabel('Count')
plt.xticks(rotation='vertical')
plt.show()

# %%
#plt.figure(figsize = (16,9))
plt.hist(df['relationship'], width = 0.5, histtype = 'bar')
plt.xlabel('relationship')
plt.ylabel('Count')
plt.xticks(rotation='vertical')
plt.show()

# %%
#plt.figure(figsize = (16,9))
sns.histplot(x=df['relationship'],hue=df['salary'],bins=15)
plt.xlabel('relationship')
plt.ylabel('Count')
plt.xticks(rotation='vertical')
plt.show()

# %%
#plt.figure(figsize = (16,9))
plt.hist(df['marital-status'], width = 0.5, histtype = 'bar')
plt.xlabel('marital-status')
plt.ylabel('Count')
plt.xticks(rotation='vertical')
plt.show()

# %%
#plt.figure(figsize = (16,9))
sns.histplot(x=df['marital-status'],hue=df['salary'],bins=15)
plt.xlabel('marital-status')
plt.ylabel('Count')
plt.xticks(rotation='vertical')
plt.show()

# %%
#plt.figure(figsize = (16,9))
plt.hist(df['race'], width = 0.5, histtype = 'bar')
plt.xlabel('race')
plt.ylabel('Count')
plt.xticks(rotation='vertical')
plt.show()

# %%
#plt.figure(figsize = (16,9))
sns.histplot(x=df['race'],hue=df['salary'],bins=15)
plt.xlabel('race')
plt.ylabel('Count')
plt.xticks(rotation='vertical')
plt.show()

# %%
#plt.figure(figsize = (16,9))
plt.hist(df['sex'], width = 0.5, histtype = 'bar')
plt.xlabel('sex')
plt.ylabel('Count')
plt.show()

# %%
#plt.figure(figsize = (16,9))
sns.histplot(x=df['sex'],hue=df['salary'],bins=15)
plt.xlabel('sex')
plt.ylabel('Count')
plt.show()

# %%
#plt.figure(figsize = (16,9))
plt.hist(df['capital-gain'], histtype = 'bar',orientation = 'horizontal')
plt.xlabel('capital-gain')
plt.ylabel('Count')
plt.show()

# %%
#plt.figure(figsize = (16,9))
sns.histplot(y=df['capital-gain'],hue=df['salary'],bins=15)
plt.xlabel('capital-gain')
plt.ylabel('Count')
plt.show()

# %%
#plt.figure(figsize = (16,9))
plt.hist(df['capital-loss'], histtype = 'bar',orientation = 'horizontal')
plt.xlabel('capital-loss')
plt.ylabel('Count')
plt.show()

# %%
#plt.figure(figsize = (16,9))
sns.histplot(y=df['capital-loss'],hue=df['salary'],bins=15)
plt.xlabel('capital-loss')
plt.ylabel('Count')
plt.show()

# %%
#plt.figure(figsize = (16,9))
plt.hist(df['hours-per-week'], width = 5, histtype = 'bar')
plt.xlabel('hours-per-week')
plt.ylabel('Count')
plt.show()

# %%
#plt.figure(figsize = (16,9))
sns.histplot(x=df['hours-per-week'],hue=df['salary'],bins=15)
plt.xlabel('hours-per-week')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize = (12,5))
plt.hist(df['country'], width = 0.5, histtype = 'bar')
plt.xlabel('country')
plt.ylabel('Count')
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.figure(figsize = (12,5))
sns.histplot(x=df['country'],hue=df['salary'],bins=15)
plt.xlabel('country')
plt.ylabel('Count')
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# # We get the following insights from visualization:
#
# -Aage group 0-20 there are not any individual of salary >50K, same occured with group <75 years.
#
# -The majority work in the private sector... and '?' == NULL value.
#
# -FnlWgt == final weight :- we were not able to find any pattern with final weight.
#
# -Pree school to 12th == Extra... Mostly individulas with higher education have higher chance of having salary >50K.
#
# -Married have a higher chance of having salary >50K as compared to unmarried.
#
# -Prof-specialty Exec-managerial have a higher rate to having salary >50K as compared to others.
#
# -We can see clearly that husband have a higher rate to having salary >50K.
#
# -As compared in the ratio white and Asian race have higher rate of salary >50K but at the same time white race have much higher entries as compared to others.
#
# -We can see clearly that male have a higher rate to having salary >50K simliar to husband and wife case.
#
# -Distribution of capital-gain is not very linear same is with capital-loss.
#
# -After simplifying hours-per-week we came to conclusion that salary increase from less than 40 hrs to 40 hrs then decrease.
#
# -Country mostly contain US which is not very helpful.

# %% [markdown]
# # Preprocessing

# %%
df.head()

logging.info('Started preprocessing.')
logging.info('Editing necessary columns values.')
logging.info('Droping NULL values.')

# %%
df['education'].unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %%
def column_edit_education(studied):
    
    if (studied==' 11th') | (studied==' 9th') | (studied==' 7th-8th') | (studied==' 5th-6th') | (studied==' 10th') | (studied==' 1st-4th') | (studied==' Preschool') | (studied==' 12th'):
        return 'Lower'
    else:
        return studied

# %%
df['education']=df['education'].apply(column_edit_education)

# %%
df['education'].unique()
# Out:
# array([' Bachelors', ' HS-grad', 'Lower', ' Masters', ' Some-college',
#        ' Assoc-acdm', ' Assoc-voc', ' Doctorate', ' Prof-school'],
#       dtype=object)

# %%
df['marital-status'].unique()
# Out:
# array([' Never-married', ' Married-civ-spouse', ' Divorced',
#        ' Married-spouse-absent', ' Separated', ' Married-AF-spouse',
#        ' Widowed'], dtype=object)

# %%
def column_edit_marital_status(status):
    if (status==' Never-married') | (status==' Divorced') | (status==' Separated') | (status==' Widowed') :
        return 'not-married'
    else:
        return 'married'

# %%
df['marital-status']=df['marital-status'].apply(column_edit_marital_status)

# %%
df['marital-status'].unique()
# Out:
# array(['not-married', 'married'], dtype=object)

# %%
df['hours-per-week'].dtype
# Out:
# dtype('int64')

# %%
def column_edit_hrs_per_week(hrs):
    if (0 < hrs < 10):
      return '<10'
    elif (10 <= hrs <= 20):
      return 'between 10,20'
    elif (21 <= hrs <= 30):
      return 'between 21,30'
    elif (31 <= hrs <= 40):
      return 'between 31,40'
    elif (41 <= hrs <= 50):
      return 'between 41,50'
    elif (51 <= hrs <= 60):
      return 'between 51,60'
    elif (61 <= hrs <= 70):
      return 'between 61,70'
    elif (71 <= hrs <= 80):
      return 'between 71,80'
    elif (81 <= hrs <= 90):
      return 'between 81,90'
    elif (91 <= hrs <= 100):
      return 'between 91,100'
    else:
      return '>100'

# %%
df['hours-per-week'] = df['hours-per-week'].apply(column_edit_hrs_per_week)

# %%
def column_edit_salary(inc):
    if inc ==  ' <=50K':
        return 'Income less than 50K'
    else:
        return 'Income More then 50K'

# %%
df['salary'] = df['salary'].apply(column_edit_salary)

# %%
df['hours-per-week'].unique()
# Out:
# array(['between 31,40', 'between 10,20', 'between 41,50', 'between 71,80',
#        'between 21,30', 'between 51,60', 'between 61,70', '<10',
#        'between 91,100', 'between 81,90'], dtype=object)

# %%
df.shape
# Out:
# (32561, 15)

# %%
df['workclass'].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
df['occupation'].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
df[df == ' ?'] = np.nan

# %%
df['occupation'].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', nan, ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
df['workclass'].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', nan, ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (30162, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30162 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             30162 non-null  int64
#  1   workclass       30162 non-null  object
#  2   fnlwgt          30162 non-null  int64
#  3   education       30162 non-null  object
#  4   education-num   30162 non-null  int64
#  5   marital-status  30162 non-null  object
#  6   occupation      30162 non-null  object
#  7   relationship    30162 non-null  object
#  8   race            30162 non-null  object
#  9   sex             30162 non-null  object
#  10  capital-gain    30162 non-null  int64
#  11  capital-loss    30162 non-null  int64
#  12  hours-per-week  30162 non-null  object
#  13  country         30162 non-null  object
#  14  salary          30162 non-null  object
# dtypes: int64(5), object(10)
# memory usage: 3.7+ MB

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Columns that will not be considered for model training are...
# 'education-num', 'relationship', 'race' and 'country','capital-gain','capital-loss'

# %%
logging.info('Feature Engineering Started.')
logging.info('Droping columns that will not be considered for model training.')
df.drop(['education-num','relationship', 'race', 'country','capital-gain','capital-loss','fnlwgt'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (30162, 8)

# %%
df.head()
# Out:
#    age          workclass   education marital-status          occupation  \
# 0   39          State-gov   Bachelors    not-married        Adm-clerical
# 1   50   Self-emp-not-inc   Bachelors        married     Exec-managerial
# 2   38            Private     HS-grad    not-married   Handlers-cleaners
# 3   53            Private       Lower        married   Handlers-cleaners
# 4   28            Private   Bachelors        married      Prof-specialty
#
#        sex hours-per-week                salary
# 0     Male  between 31,40  Income less than 50K
# 1     Male  between 10,20  Income less than 50K
# 2     Male  between 31,40  Income less than 50K
# 3     Male  between 31,40  Income less than 50K
# 4   Female  between 31,40  Income less than 50K

# %%
logging.info('Used OneHot Encoding.')

# %%
df.rename(columns = {'hours-per-week':'hours_per_week'}, inplace = True)
df.rename(columns = {'marital-status':'marital_status'}, inplace = True)

# %%
df['workclass'].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' Self-emp-inc', ' Without-pay'], dtype=object)

# %%
df['education'].unique()
# Out:
# array([' Bachelors', ' HS-grad', 'Lower', ' Masters', ' Some-college',
#        ' Assoc-acdm', ' Doctorate', ' Assoc-voc', ' Prof-school'],
#       dtype=object)

# %%
df['marital_status'].unique()
# Out:
# array(['not-married', 'married'], dtype=object)

# %%
df['occupation'].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Transport-moving',
#        ' Farming-fishing', ' Machine-op-inspct', ' Tech-support',
#        ' Craft-repair', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
df['sex'].unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
df['hours_per_week'].unique()
# Out:
# array(['between 31,40', 'between 10,20', 'between 41,50', 'between 71,80',
#        'between 21,30', 'between 51,60', 'between 61,70', '<10',
#        'between 91,100', 'between 81,90'], dtype=object)

# %%
from sklearn.compose import ColumnTransformer 
from sklearn.preprocessing import OneHotEncoder

trf = ColumnTransformer([
    ('trf', OneHotEncoder(sparse=False, drop='first'),['workclass','education','marital_status',
                                                      'occupation','sex','hours_per_week'])]
    ,remainder='passthrough')


logging.info('Used OneHot Encoding.')

# %%
df['occupation'].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Transport-moving',
#        ' Farming-fishing', ' Machine-op-inspct', ' Tech-support',
#        ' Craft-repair', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
df
# Out:
#        age          workclass    education marital_status          occupation  \
# 0       39          State-gov    Bachelors    not-married        Adm-clerical
# 1       50   Self-emp-not-inc    Bachelors        married     Exec-managerial
# 2       38            Private      HS-grad    not-married   Handlers-cleaners
# 3       53            Private        Lower        married   Handlers-cleaners
# 4       28            Private    Bachelors        married      Prof-specialty
# ...    ...                ...          ...            ...                 ...
# 32556   27            Private   Assoc-acdm        married        Tech-support
# 32557   40            Private      HS-grad        married   Machine-op-inspct
# 32558   58            Private      HS-grad    not-married        Adm-clerical
# 32559   22            Private      HS-grad    not-married        Adm-clerical
# 32560   52       Self-emp-inc      HS-grad        married     Exec-managerial
#
# ...

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# education         object
# marital_status    object
# occupation        object
# sex               object
# hours_per_week    object
# salary            object
# dtype: object

# %%
df
# Out:
#        age          workclass    education marital_status          occupation  \
# 0       39          State-gov    Bachelors    not-married        Adm-clerical
# 1       50   Self-emp-not-inc    Bachelors        married     Exec-managerial
# 2       38            Private      HS-grad    not-married   Handlers-cleaners
# 3       53            Private        Lower        married   Handlers-cleaners
# 4       28            Private    Bachelors        married      Prof-specialty
# ...    ...                ...          ...            ...                 ...
# 32556   27            Private   Assoc-acdm        married        Tech-support
# 32557   40            Private      HS-grad        married   Machine-op-inspct
# 32558   58            Private      HS-grad    not-married        Adm-clerical
# 32559   22            Private      HS-grad    not-married        Adm-clerical
# 32560   52       Self-emp-inc      HS-grad        married     Exec-managerial
#
# ...

# %%
X = df[['age', 'workclass', 'education', 'marital_status', 'occupation',
      'sex', 'hours_per_week']]
y = df['salary']

# %%
from sklearn.model_selection import train_test_split
logging.info('Distributed data into training and testing data.')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.8,random_state = 120)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((24129, 7), (6033, 7), (24129,), (6033,))

# %%
newdf = df

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_workclass = LabelEncoder()
newdf['workclass'] = le_workclass.fit_transform(newdf['workclass'])
newdf['workclass'].unique()
# Out:
# array([5, 4, 2, 0, 1, 3, 6])

# %%
le_education = LabelEncoder()
newdf['education'] = le_education.fit_transform(newdf['education'])
newdf['education'].unique()
# Out:
# array([2, 4, 8, 5, 7, 0, 3, 1, 6])

# %%
le_marital_status = LabelEncoder()
newdf['marital_status'] = le_marital_status.fit_transform(newdf['marital_status'])
newdf['marital_status'].unique()
# Out:
# array([1, 0])

# %%
le_occupation = LabelEncoder()
newdf['occupation'] = le_occupation.fit_transform(newdf['occupation'])
newdf['occupation'].unique()
# Out:
# array([ 0,  3,  5,  9,  7, 11, 13,  4,  6, 12,  2, 10,  1,  8])

# %%
le_sex = LabelEncoder()
newdf['sex'] = le_sex.fit_transform(newdf['sex'])
newdf['sex'].unique()
# Out:
# array([1, 0])

# %%
le_hours_per_week = LabelEncoder()
newdf['hours_per_week'] = le_hours_per_week.fit_transform(newdf['hours_per_week'])
newdf['hours_per_week'].unique()
# Out:
# array([3, 1, 4, 7, 2, 5, 6, 0, 9, 8])

# %%
le_salary = LabelEncoder()
newdf['salary'] = le_salary.fit_transform(newdf['salary'])
newdf['salary'].unique()
# Out:
# array([1, 0])

# %%
X1 = newdf[['age', 'workclass', 'education', 'marital_status', 'occupation',
      'sex', 'hours_per_week']]
y1 = newdf['salary']

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, train_size = 0.8,random_state = 120)

# %%
X1_train.shape, X1_test.shape, y1_train.shape, y1_test.shape
# Out:
# ((24129, 7), (6033, 7), (24129,), (6033,))

# %%
newdf['workclass']
# Out:
# 0        5
# 1        4
# 2        2
# 3        2
# 4        2
#         ..
# 32556    2
# 32557    2
# 32558    2
# 32559    2
# 32560    3
# Name: workclass, Length: 30162, dtype: int32

# %% [markdown]
# ## Searching best model to use...

# %%
logging.info('Testing different model.')
logging.info('Searching best model to use.')

from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
lr.fit(X1_train, y1_train)
lr.score(X1_test, y1_test)
# Out:
# C:\conda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7821979114868225

# %%
from sklearn.neighbors import KNeighborsClassifier
neighbor = KNeighborsClassifier()

# %%
neighbor.fit(X1_train, y1_train)
neighbor.score(X1_test, y1_test)
# Out:
# C:\conda\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# 0.7991049229239184

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()

# %%
gnb.fit(X1_train, y1_train)
gnb.score(X1_test, y1_test)
# Out:
# 0.7641306149511022

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier()

# %%
tree.fit(X1_train, y1_train)
tree.score(X1_test, y1_test)
# Out:
# 0.7719211006132936

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200,max_depth=5, min_samples_leaf=100,n_jobs=4,random_state=22)

# %%
rf.fit(X1_train, y1_train)
rf.score(X1_test, y1_test)

logging.info('Random Forest gives best results.')

# %%
from sklearn.pipeline import Pipeline
pipe = Pipeline(steps = [
    ('step1',trf),
    ('step2',RandomForestClassifier(n_estimators=200,max_depth=5, min_samples_leaf=100,n_jobs=4,random_state=22))
])

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['workclass', 'education',
#                                                    'marital_status',
#                                                    'occupation', 'sex',
#                                                    'hours_per_week'])])),
#                 ('step2',
#                  RandomForestClassifier(max_depth=5, min_samples_leaf=100,
#                                         n_estimators=200, n_jobs=4,
#                                         random_state=22))])

# %%
y_pred = pipe.predict(X_test)

# %%
y_pred
# Out:
# array(['Income less than 50K', 'Income less than 50K',
#        'Income less than 50K', ..., 'Income less than 50K',
#        'Income less than 50K', 'Income less than 50K'], dtype=object)

# %% [markdown]
# ## Random Forest gives us the highest accuracy...
